# %%
import pandas as pd
import json
import regex as re
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
survey_responses = pd.read_csv('Acquisition Headline Survey (RAs)_September 16, 2021_16.22.csv', header = 0).iloc[2:6]
survey_responses.head()
# Out:
#              StartDate              EndDate      Status        IPAddress  \
# 2  2021-09-06 07:51:28  2021-09-06 08:37:41  IP Address  105.224.245.191
# 3  2021-09-06 16:06:43  2021-09-06 16:37:51  IP Address      24.2.51.110
# 4  2021-09-06 17:53:24  2021-09-06 18:46:38  IP Address    17.149.237.19
# 5  2021-09-12 10:03:42  2021-09-12 10:55:28  IP Address    71.197.104.14
#
#   Progress Duration (in seconds) Finished         RecordedDate  \
# 2      100                  2772     True  2021-09-06 08:37:43
# 3      100                  1868     True  2021-09-06 16:37:53
# 4      100                  3193     True  2021-09-06 18:46:40
# 5      100                  3105     True  2021-09-12 10:55:30
#
#           ResponseId RecipientLastName  ... QID1997_Last Click  \
# 2  R_2rIcxXbduKRm5Pz               NaN  ...                NaN
# 3  R_3p5aquR34erFk4X               NaN  ...              2.982
# 4  R_9tcAJbXXKWkH8I1               NaN  ...                NaN
# 5  R_1l4ativArU3826A               NaN  ...                NaN
#
#   QID1997_Page Submit QID1997_Click Count QID1999 QID2000   QID2001  \
# 2                 NaN                 NaN     Yes   Danoo  Ideacast
# 3               5.476                   1     NaN     NaN       NaN
# 4                 NaN                 NaN     NaN     NaN       NaN
# 5                 NaN                 NaN     NaN     NaN       NaN
#
#   QID2002_First Click QID2002_Last Click QID2002_Page Submit  \
# 2                4.09             12.953              15.062
# 3                 NaN                NaN                 NaN
# 4                 NaN                NaN                 NaN
# 5                 NaN                NaN                 NaN
#
#   QID2002_Click Count
# 2                   5
# 3                 NaN
# 4                 NaN
# 5                 NaN
#
# [4 rows x 2818 columns]

# %%
survey_responses.columns
# Out:
# Index(['StartDate', 'EndDate', 'Status', 'IPAddress', 'Progress',
#        'Duration (in seconds)', 'Finished', 'RecordedDate', 'ResponseId',
#        'RecipientLastName',
#        ...
#        'QID1997_Last Click', 'QID1997_Page Submit', 'QID1997_Click Count',
#        'QID1999', 'QID2000', 'QID2001', 'QID2002_First Click',
#        'QID2002_Last Click', 'QID2002_Page Submit', 'QID2002_Click Count'],
#       dtype='object', length=2818)

# %%
start = 4
end = 2003
subparts = 4
acq_status = []
acquirers = []
acquireds = []
completion_time = []
student_val = []

for student in range(0, 4):
    row = survey_responses.iloc[student]
    for i in range(start, end, subparts + 1):
        student_val.append(student)
        for q in range(subparts):
            curr = i + q
            q_name = 'QID{}'.format(curr)

            if q == 0:
                acq_status.append(row[q_name])
            elif q == 1:
                acquirers.append(row[q_name])
            elif q == 2:
                acquireds.append(row[q_name])
            else:
                completion_time.append(float(row[q_name + '_Page Submit']) - float(row[q_name + '_First Click']))
    print('Student', student, 'done')
# Out:
# Student 0 done
# Student 1 done
# Student 2 done
# Student 3 done

# %%
len(acquireds)
# Out:
# 1600

# %%
survey_responses_clean = pd.DataFrame({
    'Acq Status': acq_status,
    'Acquirer': acquirers,
    'Acquired': acquireds,
    'Completion Time': completion_time,
    'Student': student_val
})

survey_responses_clean
# Out:
#      Acq Status    Acquirer  \
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
# ...         ...         ...
# 1595        NaN         NaN
# 1596        Yes  Investcorp
# 1597        Yes         PSS
# 1598        NaN         NaN
# 1599        NaN         NaN
#
#                                                Acquired  Completion Time  \
# 0                                                   NaN              NaN
# 1                                                   NaN              NaN
# 2                                                   NaN              NaN
# 3                                                   NaN              NaN
# 4                                                   NaN              NaN
# ...                                                 ...              ...
# 1595                                                NaN              NaN
# 1596  30% stake in leading Turkish menswear retailer...           18.230
# 1597                                               INSI            4.057
# 1598                                                NaN              NaN
# 1599                                                NaN              NaN
#
#       Student
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 1595        3
# 1596        3
# 1597        3
# 1598        3
# 1599        3
#
# [1600 rows x 5 columns]

# %%
# add column for question headline
questions = []
with open('qualtrics_survey.qsf') as f:
    survey = json.load(f)
    for i in range(start + 1, end, subparts + 1):
        curr = re.search('[0-9]*. Headline:(.*)', survey['SurveyElements'][i]['SecondaryAttribute']).group(1).strip()
        questions.append(curr)

# %%
# rows that have only na
null_data = survey_responses_clean[survey_responses_clean.isnull().all(axis = 1)]
null_data.shape
# Out:
# (0, 5)

# %%
survey_responses_clean['Headline'] = questions + questions + questions + questions
survey_responses_clean
# Out:
#      Acq Status    Acquirer  \
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
# ...         ...         ...
# 1595        NaN         NaN
# 1596        Yes  Investcorp
# 1597        Yes         PSS
# 1598        NaN         NaN
# 1599        NaN         NaN
#
#                                                Acquired  Completion Time  \
# 0                                                   NaN              NaN
# 1                                                   NaN              NaN
# 2                                                   NaN              NaN
# 3                                                   NaN              NaN
# 4                                                   NaN              NaN
# ...                                                 ...              ...
# 1595                                                NaN              NaN
# 1596  30% stake in leading Turkish menswear retailer...           18.230
# 1597                                               INSI            4.057
# 1598                                                NaN              NaN
# 1599                                                NaN              NaN
#
#       Student                                           Headline
# 0           0  Better Place Sold To Sunrise Group For $12 Mil...
# 1           0  Action App Corporation (OTC: ANDI) Buys Anothe...
# 2           0          Docmail Connect for Google Apps launched!
# 3           0  Rent My Vacation Home ( RMVH network)Opens Ren...
# 4           0  Entech Solar Enters Into Preferred Stock Agree...
# ...       ...                                                ...
# 1595        3            Spanish buyer set to take over Talecris
# 1596        3  Investcorp Buys 30% Stake In Leading Turkish M...
# 1597        3  Preferred Systems Solutions, Inc. (PSS), annou...
# 1598        3  Yellow Media Sells Vertical Media Publishing S...
# 1599        3     Danoo and Ideacast to relaunch as RMG Networks
#
# [1600 rows x 6 columns]

# %%
survey_responses_clean = survey_responses_clean[survey_responses_clean['Acq Status'].notna()]
survey_responses_clean
# Out:
#      Acq Status                            Acquirer  \
# 6      Not sure                        Entuboca.com
# 8           Yes                             Level 3
# 12          Yes                    Sugar Publishing
# 14     Not sure                             Invitel
# 15          Yes  Kratos Defense & Security Solution
# ...         ...                                 ...
# 1584        Yes                                 ABB
# 1586        Yes                             Filogix
# 1589        Yes                             Praxair
# 1596        Yes                          Investcorp
# 1597        Yes                                 PSS
#
#                                                Acquired  Completion Time  \
# 6                                           Nevera Roja           29.711
# 8                                       Global Crossing           22.740
# 12                                            ShopStyle           11.800
# 14                                             Fibernet           19.767
# 15                                 Digital Fusion, Inc.           14.470
# ...                                                 ...              ...
# 1584                                             Mincom            4.691
# 1586                           Cyence International Inc            7.786
# 1589                                       Dominion Gas           14.198
# 1596  30% stake in leading Turkish menswear retailer...           18.230
# 1597                                               INSI            4.057
#
#       Student                                           Headline
# 6           0                 La Nevera Roja compra Entuboca.com
# 8           0  Level 3 To Acquire Global Crossing For $3 Bill...
# 12          0                Sugar Publishing Acquires ShopStyle
# 14          0  Invitel Reaches Sale and purchase Agreement fo...
# 15          0  Kratos Defense & Security Solutions Completes ...
# ...       ...                                                ...
# 1584        3   ABB Buys Another One: MIncom, for Managing Mines
# 1586        3       Filogix To Acquire Cyence International Inc.
# 1589        3                      Praxair Acquires Dominion Gas
# 1596        3  Investcorp Buys 30% Stake In Leading Turkish M...
# 1597        3  Preferred Systems Solutions, Inc. (PSS), annou...
#
# [500 rows x 6 columns]

# %%
# avg completion time
clean_times = survey_responses_clean.loc[survey_responses_clean['Completion Time'].notna()]['Completion Time']
print('Avg time / question', sum(clean_times) / len(clean_times))
# Out:
# Avg time / question 11.600358

# %%
print(np.median(np.extract(clean_times < 50, clean_times)))
# Out:
# 9.276500000000002

# %%
for curr_student in range(4):
    clean_times_curr = survey_responses_clean.loc[survey_responses_clean['Student'] == curr_student].loc[survey_responses_clean['Completion Time'].notna()]['Completion Time']
    print('Student {}'.format(curr_student))
    print(np.median(clean_times_curr))
    print(np.mean(clean_times_curr))
    print()
# Out:
# Student 0
# 10.76
# 12.051688
#
# Student 1
# 9.93
# 10.596184
#
# Student 2
# 9.068999999999999
# 12.37284
#
# Student 3
# 7.313
# 11.380720000000002

# %%
print(np.var(np.extract(clean_times < 50, clean_times)))
# Out:
# 45.739530042977265

# %%
plt.figure(figsize = (15, 12))
sns.histplot(survey_responses_clean['Completion Time'])

# %%
survey_responses_clean.to_csv('survey_responses_clean.csv')

# %%
# number of unique headlines classified
print('Unique headlines classified', len(np.unique(survey_responses_clean['Headline'])))
# Out:
# Unique headlines classified 373

# %%
list(survey_responses_clean.loc[survey_responses_clean['Acq Status'] == 'Not sure']['Headline'])
# Out:
# ['La Nevera Roja compra Entuboca.com',
#  'Invitel Reaches Sale and purchase Agreement for Fibernet',
#  'Allscripts HIMSS Press Release',
#  'Oomba Inc. Engages MZ Group for Investor Relations',
#  'Trendrr Appoints Alex Mann, Founder of AM Analytics, its Director',
#  'Syncables to Demonstrate Wireless Syncing of Computers and Phones with Syncables® 360 and Intel® My WiFi Technology at Computex',
#  'Internet Brands Buys Two Web Sites, Looks To Future Acquisitions',
#  'Visumotion Changes Name to 3D International Group',
#  'RedAlumnos supera los 50.000 usuarios',
#  'InQvent-backed healthcare services firm Alacurity eyes up to $5M in Series A funding',
#  'Stemgent to buy Asterand�s human tissue biz for $9M',
#  "TCA's Ralph Mayer Joins Angel Capital Association Board",
#  'Clavis Secures Funding from Enterprise Ireland',
#  'SYNETY eyes global expansion with proposed reverse AIM listing',
#  'One Two Trade Forex',
#  "'Telefonica confirms Tuenti stake acquisition'",
#  'CodeTwo Attains Microsoft Certified Partner Status',
#  'Carpathia Hosting Names Michael Fox Director of Sales, Public Sector',
#  'Onetime IPO Candidate Wintegra Bought By PMC-Sierra',
#  'In The Shadow Of YouTube, Vuclip Grows Its Mobile Video Network To 80M Uniques, Fends Off Suitors And Eyes Up Acquisitions',
#  'AeroMechanical Services Ltd. Acquires Assets of Wingspeed Corporation',
#  'Infotech Enterprises announces its foray into the Hitech industry with Design services',
#  'Westaim Announces Amalgamation Agreement with NUCRYST Pharmaceuticals',
#  'Dell Shops Direct For Zing',
#  'Plum Creek buys Atlanta quarry interest for $154M',
#  'Zynex Enters into Letter of Intent with NeuroDyne Medical, Corp.',
#  'Netural holt sich Mark Kramer',
#  'Teradata Quiet on Plans for Database Virtualization Vendor xkoto',
#  'Komli Media Expands Aggressively Across Asia-Pacific',
#  'Sina Afra invests in Lidyana',
#  'Entelos pays up to $39M for Iconix Biosciences',
#  'Big news - Rackspace and Slicehost',
#  'Danoo and Ideacast to relaunch as RMG Networks',
#  'Construction sector organizations in 100 percent ownership Tilaajavastuu Finland O',
#  'Athenahealth to pay up to $30M for Georgia firm',
#  'BETACOM SA CONNECTS TO THE EO NETWORKS SA',
#  'Carbox boucle une 3�me lev�e aupr�s de Mobivia Groupe',
#  'Russian ISP Siberian Networks sells 20% ownership to CapMan',
#  'Softscape acquired by competing software firm',
#  'Russian ISP Siberian Networks sells 20% ownership to CapMan',
#  'Dell Shops Direct For Zing',
#  'SonicWALL Acquired By Private Equity Group For $717M',
#  'Выгода.ру – победитель народного голосования «Выбор потребителей 2011″!',
#  'Oxford University Hospitals NHS proves outstanding compliance levels with Enterprise Study',
#  "Boston's Rue La La gets shuffled in eBay-GSI merger",
#  'SYNETY eyes global expansion with proposed reverse AIM listing',
#  'CallSource Appoints Brad Barnett as President',
#  'Fenox Venture Capital Invests in Southeast Asian Technology Media Startup Tech in Asia',
#  'MethylGene Shareholders Approve the Plan of Arrangement to Reincorporate in the United States as Mirati Therapeutics Inc.',
#  'Unity Wireless Closes Acquisition of Celletra Ltd.',
#  'Memphis Networx Now Part of Zayo Bandwidth',
#  'Music Tech Pioneers Combine to Create Premier Site for Collaboration',
#  "Nuance Communications To Buy QuadraMed's Health Information Management Business",
#  'UFG PE Part of Three-way Deal to Purchase Rising Star Media',
#  'SAP Will Buy SuccessFactors For $3.4 BillionSAP Will Buy SuccessFactors For $3.4 Billion',
#  'EMC to complete Isilon buyout Tuesday',
#  'Baidu to Buy 59% of Renren�s Group-buying Service Nuomi for $160 million',
#  'Sitemasher sold and winding down... but to whom?',
#  'DiACardio LTD, & UltraLinq Healthcare Solutions Announce Partnership',
#  'UBM Boost Online PR Business With $10 Million Virtual Press Office Acquisition',
#  'TypeFrag Selects Internap to Deliver High-Performance Network for Online Gaming VoIP']

# %%
# how many rows are unsure?
survey_responses_clean['Acq Status'].value_counts()
# Out:
# Yes               248
# No                152
# Not sure           61
# Not a headline     39
# Name: Acq Status, dtype: int64

# %%
# consensus vote on acq status / acquirer / acquired
def most_common(lst):
    return max(set(lst), key = lst.count)

def func(x):
    acq_status = most_common(list(x['Acq Status']))
    acquirer = most_common(list(x['Acquirer']))
    acquired = most_common(list(x['Acquired']))
    y = pd.DataFrame({'Acq Status': [acq_status], 'Acquirer': [acquirer], 'Acquired': [acquired]})
    return y
    
consensus = survey_responses_clean.groupby('Headline').apply(func).reset_index().drop(columns = ['level_1'])
consensus = consensus.loc[:,~consensus.columns.duplicated()]
consensus
# Out:
#                                               Headline      Acq Status  \
# 0       'Telefonica confirms Tuenti stake acquisition'        Not sure
# 1    11 Billion Videos Viewed Online in the U.S. in...  Not a headline
# 2          140 Proof Social Advertising Product Launch              No
# 3             3 Key Reasons Facebook Bought FriendFeed             Yes
# 4    3 Rules You Must Follow If You Want Your Compa...              No
# ..                                                 ...             ...
# 368                       myOpenID Affiliate Blog Post  Not a headline
# 369          product inconsistency (it's a good thing)  Not a headline
# 370         stack.horizobu.com - an exploration engine  Not a headline
# 371               urlShort breaks 1,000 shortened URLs              No
# 372  Выгода.ру – победитель народного голосования «...        Not sure
#
#        Acquirer    Acquired
# 0    Telefonica      Tuenti
# 1           NaN         NaN
# 2           NaN         NaN
# 3      Facebook  FriendFeed
# 4           NaN         NaN
# ..          ...         ...
# 368         NaN         NaN
# 369         NaN         NaN
# 370         NaN         NaN
# 371         NaN         NaN
# 372         NaN         NaN
#
# [373 rows x 4 columns]

# %%
consensus['Acq Status'].value_counts()
# Out:
# Yes               182
# No                108
# Not sure           56
# Not a headline     27
# Name: Acq Status, dtype: int64

# %%
consensus.to_csv('consensus.csv')

# %%
# what are the remaining not sure headlines?
list(consensus.loc[consensus['Acq Status'] == 'Not sure']['Headline'])
# Out:
# ["'Telefonica confirms Tuenti stake acquisition'",
#  'AeroMechanical Services Ltd. Acquires Assets of Wingspeed Corporation',
#  'Allscripts HIMSS Press Release',
#  'Athenahealth to pay up to $30M for Georgia firm',
#  'BETACOM SA CONNECTS TO THE EO NETWORKS SA',
#  'Baidu to Buy 59% of Renren�s Group-buying Service Nuomi for $160 million',
#  'Big news - Rackspace and Slicehost',
#  "Boston's Rue La La gets shuffled in eBay-GSI merger",
#  'CallSource Appoints Brad Barnett as President',
#  'Carbox boucle une 3�me lev�e aupr�s de Mobivia Groupe',
#  'Carpathia Hosting Names Michael Fox Director of Sales, Public Sector',
#  'Clavis Secures Funding from Enterprise Ireland',
#  'CodeTwo Attains Microsoft Certified Partner Status',
#  'Construction sector organizations in 100 percent ownership Tilaajavastuu Finland O',
#  'Dell Shops Direct For Zing',
#  'DiACardio LTD, & UltraLinq Healthcare Solutions Announce Partnership',
#  'EMC to complete Isilon buyout Tuesday',
#  'Entelos pays up to $39M for Iconix Biosciences',
#  'Fenox Venture Capital Invests in Southeast Asian Technology Media Startup Tech in Asia',
#  'In The Shadow Of YouTube, Vuclip Grows Its Mobile Video Network To 80M Uniques, Fends Off Suitors And Eyes Up Acquisitions',
#  'InQvent-backed healthcare services firm Alacurity eyes up to $5M in Series A funding',
#  'Infotech Enterprises announces its foray into the Hitech industry with Design services',
#  'Internet Brands Buys Two Web Sites, Looks To Future Acquisitions',
#  'Invitel Reaches Sale and purchase Agreement for Fibernet',
#  'Komli Media Expands Aggressively Across Asia-Pacific',
#  'La Nevera Roja compra Entuboca.com',
#  'Memphis Networx Now Part of Zayo Bandwidth',
#  'MethylGene Shareholders Approve the Plan of Arrangement to Reincorporate in the United States as Mirati Therapeutics Inc.',
#  'Music Tech Pioneers Combine to Create Premier Site for Collaboration',
#  'Netural holt sich Mark Kramer',
#  'One Two Trade Forex',
#  'Onetime IPO Candidate Wintegra Bought By PMC-Sierra',
#  'Oomba Inc. Engages MZ Group for Investor Relations',
#  'Oxford University Hospitals NHS proves outstanding compliance levels with Enterprise Study',
#  'Plum Creek buys Atlanta quarry interest for $154M',
#  'RedAlumnos supera los 50.000 usuarios',
#  'Russian ISP Siberian Networks sells 20% ownership to CapMan',
#  'SAP Will Buy SuccessFactors For $3.4 BillionSAP Will Buy SuccessFactors For $3.4 Billion',
#  'SYNETY eyes global expansion with proposed reverse AIM listing',
#  'Sina Afra invests in Lidyana',
#  'Sitemasher sold and winding down... but to whom?',
#  'Softscape acquired by competing software firm',
#  'SonicWALL Acquired By Private Equity Group For $717M',
#  'Stemgent to buy Asterand�s human tissue biz for $9M',
#  'Syncables to Demonstrate Wireless Syncing of Computers and Phones with Syncables® 360 and Intel® My WiFi Technology at Computex',
#  "TCA's Ralph Mayer Joins Angel Capital Association Board",
#  'Teradata Quiet on Plans for Database Virtualization Vendor xkoto',
#  'Trendrr Appoints Alex Mann, Founder of AM Analytics, its Director',
#  'TypeFrag Selects Internap to Deliver High-Performance Network for Online Gaming VoIP',
#  'UBM Boost Online PR Business With $10 Million Virtual Press Office Acquisition',
#  'UFG PE Part of Three-way Deal to Purchase Rising Star Media',
#  'Unity Wireless Closes Acquisition of Celletra Ltd.',
#  'Visumotion Changes Name to 3D International Group',
#  'Westaim Announces Amalgamation Agreement with NUCRYST Pharmaceuticals',
#  'Zynex Enters into Letter of Intent with NeuroDyne Medical, Corp.',
#  'Выгода.ру – победитель народного голосования «Выбор потребителей 2011″!']

# %%
# what are the remaining not a headlines?
list(consensus.loc[consensus['Acq Status'] == 'Not a headline']['Headline'])
# Out:
# ['11 Billion Videos Viewed Online in the U.S. in April 2008',
#  'Android mobile platform, �up to� $US50 million (estimated)',
#  'Conker enter Wayra accelerator',
#  'Current’s Claims of ‘Profitability’ Ring False',
#  'EditMe - Reviews by PC Magazine',
#  'EnerNOC Q3 revenue jumps on customer growth',
#  'Follow Reuters      Facebook     Twitter     RSS     YouTube    Pictures Visitors run away from waves from a tidal bore as it surges past a barrier on the banks of Qiantang River, in Hangzhou Zhejiang province, August 25, 2013. REUTERS/Stringer Reuters P',
#  'Glu Mobile Expands Real-Money Gambling Portfolio with Probability',
#  'Joobili almost back from the deadpool, finds buyer for assets with sale to TravelShark',
#  'Keep Your Little Ghosts & Goblins Safe From Ghouls This Halloween',
#  'Learn Arabic on busuu.com',
#  'MassHighTech: The Journal of New England Technology',
#  'Meredith 10-q for Dec 2010',
#  'Pitchengine Social Media Release',
#  'The View Hot Topics - Ashley Madison, Cheating and Infidelity Web site',
#  'This is what developing for Android looks like',
#  'Top 50 Article Directories List',
#  'Values of n Blog',
#  'Vinnex International Championship 2010',
#  'Yahoo Spins Off Blo.gs To Automattic',
#  'myOpenID Affiliate Blog Post',
#  'stack.horizobu.com - an exploration engine']
